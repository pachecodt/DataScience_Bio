# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'
dados = pd.read_csv(url_dados, compression = 'zip')
dados_resultados = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_resultados.csv?raw=true')

dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [23814 rows x 877 columns]

# %% [markdown]
# # Aula 04

# %%
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_resultados['acetylcholine_receptor_agonist'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# Os resultados são 0 ou 1, 0 para ativam ou não esse mecânismo de ação

# %%
contagem_moa = dados_resultados.select_dtypes('int64').sum().sort_values(ascending=False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %% [markdown]
# Forma alternativa

# %%
contagem_moa = dados_resultados.drop('id', axis=1).sum().sort_values(ascending=False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
dados_resultados.drop('id', axis=1).sum(axis=1)
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %%
dados_resultados['n_moa'] = dados_resultados.drop('id', axis=1).sum(axis=1)

# %%
dados_resultados['ativo_moa'] = (dados_resultados['n_moa'] != 0)
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      2       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      6       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      2       True
#
# [5 rows x 209 columns]

# %%
dados_combinados = pd.merge(dados, dados_resultados[['id','n_moa', 'ativo_moa']], on='id')
dados_combinados
# Out:
#                  id    tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0      id_000644bb2     com_droga     24   D1  ...  0.3801  0.4176      2       True
# 1      id_000779bfc     com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2      id_000a6266a     com_droga     48   D1  ... -1.4080  0.6931      6       True
# 3      id_0015fd391     com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4      id_001626bd3     com_droga     72   D2  ... -0.3786  0.7125      2       True
# ...             ...           ...    ...  ...  ...     ...     ...    ...        ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.5258  0.4680      2       True
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2715  0.3689      2       True
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.6656  0.3808      0      False
# 23812  id_fffcb9e7c     com_droga     24   D1  ... -0.6290  0.0740      2       True
# 23813  id_ffffdd77b     com_droga     72   D1  ... -2.1500 -4.2520      0      False
#
# [23814 rows x 879 columns]

# %%
dados_combinados.query('tratamento == "com_controle"')['ativo_moa'].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
dados_combinados.query('tratamento == "com_droga"')['ativo_moa'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %%
compostos_principais = dados_combinados['droga'].value_counts().index[:6]
plt.figure(figsize=(12,8))
sns.boxplot(data = dados_combinados.query('droga in @compostos_principais'), y = 'g-0', x = 'droga', hue='ativo_moa')

# %% [markdown]
# #Desafios 04

# %% [markdown]
# ##Desafio 01: Encontrar o top 10 das ações do MOA(inibidor, agonista...)

# %%
top_moa = dados_resultados.drop(['id'], axis=1).sum().sort_values(ascending=False)
top_moa
# Out:
# n_moa                                         33688
# ativo_moa                                     14447
# nfkb_inhibitor                                  832
# proteasome_inhibitor                            726
# cyclooxygenase_inhibitor                        435
#                                               ...
# steroid                                           6
# nicotinic_receptor_agonist                        6
# elastase_inhibitor                                6
# erbb2_inhibitor                                   1
# atp-sensitive_potassium_channel_antagonist        1
# Length: 208, dtype: int64

# %%
top_moa.filter(like='_inhibitor').head(10)
# Out:
# nfkb_inhibitor              832
# proteasome_inhibitor        726
# cyclooxygenase_inhibitor    435
# dna_inhibitor               402
# cdk_inhibitor               340
# egfr_inhibitor              336
# tubulin_inhibitor           316
# pdgfr_inhibitor             297
# hmgcr_inhibitor             283
# flt3_inhibitor              279
# dtype: int64

# %%
top_moa.filter(like='_antagonist').head(10)
# Out:
# dopamine_receptor_antagonist         424
# serotonin_receptor_antagonist        404
# glutamate_receptor_antagonist        367
# adrenergic_receptor_antagonist       360
# acetylcholine_receptor_antagonist    301
# histamine_receptor_antagonist        241
# gaba_receptor_antagonist             165
# cc_chemokine_receptor_antagonist     102
# potassium_channel_antagonist          98
# opioid_receptor_antagonist            96
# dtype: int64

# %%
top_moa.filter(like='_agonist').head(10)
# Out:
# adrenergic_receptor_agonist        270
# glucocorticoid_receptor_agonist    266
# serotonin_receptor_agonist         236
# acetylcholine_receptor_agonist     190
# estrogen_receptor_agonist          158
# dopamine_receptor_agonist          121
# progesterone_receptor_agonist      119
# ppar_receptor_agonist              115
# gaba_receptor_agonist              106
# glutamate_receptor_agonist          74
# dtype: int64

# %%
top_moa.filter(like='_activator').head(10)
# Out:
# potassium_channel_activator    55
# caspase_activator              18
# nrf2_activator                 18
# ampk_activator                 12
# adenylyl_cyclase_activator     12
# dtype: int64

# %%
top_moa.filter(like='_agent').head(10)
# Out:
# chelating_agent         54
# mucolytic_agent         48
# dna_alkylating_agent    48
# dtype: int64

# %%
top_moa.filter(like='_blocker').head(10)
# Out:
# calcium_channel_blocker     281
# chloride_channel_blocker     42
# dtype: int64

# %% [markdown]
# ## Desafio 02: Criar a coluna eh_controle para quando na linha tratamento == com_controle

# %%
pd.get_dummies(dados, columns=['tratamento'], dtype=float)
# Out:
#                  id  tempo  ... tratamento_com_controle tratamento_com_droga
# 0      id_000644bb2     24  ...                     0.0                  1.0
# 1      id_000779bfc     72  ...                     0.0                  1.0
# 2      id_000a6266a     48  ...                     0.0                  1.0
# 3      id_0015fd391     48  ...                     0.0                  1.0
# 4      id_001626bd3     72  ...                     0.0                  1.0
# ...             ...    ...  ...                     ...                  ...
# 23809  id_fffb1ceed     24  ...                     0.0                  1.0
# 23810  id_fffb70c0c     24  ...                     0.0                  1.0
# 23811  id_fffc1c3f4     48  ...                     1.0                  0.0
# 23812  id_fffcb9e7c     24  ...                     0.0                  1.0
# 23813  id_ffffdd77b     72  ...                     0.0                  1.0
#
# [23814 rows x 878 columns]

# %% [markdown]
# ## Desafio 03: Criar três colunas para indicar o tempo 24, 48, 72

# %%
pd.get_dummies(dados, columns=['tempo'], dtype=float)
# Out:
#                  id    tratamento dose  ... tempo_24  tempo_48  tempo_72
# 0      id_000644bb2     com_droga   D1  ...      1.0       0.0       0.0
# 1      id_000779bfc     com_droga   D1  ...      0.0       0.0       1.0
# 2      id_000a6266a     com_droga   D1  ...      0.0       1.0       0.0
# 3      id_0015fd391     com_droga   D1  ...      0.0       1.0       0.0
# 4      id_001626bd3     com_droga   D2  ...      0.0       0.0       1.0
# ...             ...           ...  ...  ...      ...       ...       ...
# 23809  id_fffb1ceed     com_droga   D2  ...      1.0       0.0       0.0
# 23810  id_fffb70c0c     com_droga   D2  ...      1.0       0.0       0.0
# 23811  id_fffc1c3f4  com_controle   D2  ...      0.0       1.0       0.0
# 23812  id_fffcb9e7c     com_droga   D1  ...      1.0       0.0       0.0
# 23813  id_ffffdd77b     com_droga   D1  ...      0.0       0.0       1.0
#
# [23814 rows x 879 columns]

# %% [markdown]
# ## Desafio 04: Estudar sobre as combinações de DF

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %% [markdown]
# Concat

# %%
df1 = pd.DataFrame( {
    "A": ["value1", "value2", "value3"],
    "B": ["value4", "value5", "value6"],
    "C": ["value7", "value8", "value9"],
    }
)
df1
# Out:
#         A       B       C
# 0  value1  value4  value7
# 1  value2  value5  value8
# 2  value3  value6  value9

# %%
df2 = pd.DataFrame( {
    "A": ["value10", "value11", "value12"],
    "B": ["value13", "value14", "value15"],
    "C": ["value16", "value17", "value18"],
    }
)
df2
# Out:
#          A        B        C
# 0  value10  value13  value16
# 1  value11  value14  value17
# 2  value12  value15  value18

# %%
df3 = pd.DataFrame( {
    "A": ["value19", "value20", "value21"],
    "B": ["value22", "value23", "value24"],
    "C": ["value25", "value26", "value27"],
    }
)
df3
# Out:
#          A        B        C
# 0  value19  value22  value25
# 1  value20  value23  value26
# 2  value21  value24  value27

# %%
df_concat_result = pd.concat([df1, df2, df3], ignore_index=True)
df_concat_result
# Out:
#          A        B        C
# 0   value1   value4   value7
# 1   value2   value5   value8
# 2   value3   value6   value9
# 3  value10  value13  value16
# 4  value11  value14  value17
# 5  value12  value15  value18
# 6  value19  value22  value25
# 7  value20  value23  value26
# 8  value21  value24  value27

# %% [markdown]
# append

# %%
df_append_result = df1.append([df2],  ignore_index=True)
df_append_result
# Out:
#          A        B        C
# 0   value1   value4   value7
# 1   value2   value5   value8
# 2   value3   value6   value9
# 3  value10  value13  value16
# 4  value11  value14  value17
# 5  value12  value15  value18

# %% [markdown]
# merge -

# %%
df_with_key1 = pd.DataFrame( {
    "key": ["key1", "key2", "key3"],
    "A": ["value1", "value2", "value3"],
    "B": ["value4", "value5", "value6"]
})
df_with_key1
# Out:
#     key       A       B
# 0  key1  value1  value4
# 1  key2  value2  value5
# 2  key3  value3  value6

# %%
df_with_key2 = pd.DataFrame( {
    "key": ["key1", "key2", "key3"],
    "A": ["value7", "value8", "value9"],
    "B": ["value10", "value11", "value12"]
})
df_with_key2
# Out:
#     key       A        B
# 0  key1  value7  value10
# 1  key2  value8  value11
# 2  key3  value9  value12

# %%
df_with_key_result = pd.merge(df_with_key1, df_with_key2, on="key")
df_with_key_result
# Out:
#     key     A_x     B_x     A_y      B_y
# 0  key1  value1  value4  value7  value10
# 1  key2  value2  value5  value8  value11
# 2  key3  value3  value6  value9  value12
